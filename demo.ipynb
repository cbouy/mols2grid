# %%
# %%capture
# setup dependencies for Google Colab
# !pip install rdkit-pypi mols2grid
# !wget https://raw.githubusercontent.com/rdkit/rdkit/master/Docs/Book/data/solubility.test.sdf

# %%
import mols2grid
from pathlib import Path
from rdkit import RDConfig
SDF_PATH = (f"{RDConfig.RDDocsDir}/Book/data/solubility.test.sdf"
            if Path(RDConfig.RDDocsDir).is_dir() else "solubility.test.sdf")

# %%
mols2grid.display(SDF_PATH,
                  # RDKit's MolDrawOptions parameters
                  fixedBondLength=25,
                  # rename fields for the output document
                  mapping={"SOL": "Solubility",
                           "SOL_classification": "Class",
                           "NAME": "Name"},
                  # set what's displayed on the grid
                  subset=["ID", "img", "Solubility"],
                  # set what's displayed on the tooltips
                  tooltip=["Name", "SMILES", "Class", "Solubility"],
                  # style for the grid labels and tooltips
                  style={"Solubility": lambda x: "color: red" if x < -3 else "color: black"})
# Out:
# <iframe class="mols2grid-iframe" width=100% height="586" frameborder="0" srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#       #mols2grid.gridcontainer {
#         display: block;
#         padding-left: 1em;
#         max-width: 820px;
#         width: 820px;
#       }
#       #mols2grid .cell {
#         border: 1px solid #cccccc;
#         text-align: center;
#         vertical-align: top;
#         max-width: 160px;
#         width: 160px;
#         font-family: &#x27;DejaVu&#x27;, sans-serif;
#         font-size: 12pt;
#         padding: 0;
#         margin: 0;
#         float: left;
#       }
#       #mols2grid .cell:hover {
#         background-color: #e7e7e7;
#       }
#       #mols2grid .cell img, #mols2grid .cell svg {
#         max-width: 100%;
#         height: auto;
#         padding: 0;
#       }
#       #mols2grid .data {
#         overflow: hidden;
#         white-space: nowrap;
#         text-overflow: ellipsis;
#         display: block;
#       }
#       #mols2grid .arrow-asc:after {
#         content: &#x27;↑&#x27;;
#         text-align: right;
#         float:right;
#       }
#       #mols2grid .arrow-desc:after {
#         content: &#x27;↓&#x27;;
#         text-align: right;
#         float:right;
#       }
#     &lt;/style&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/list.js/2.3.1/list.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/css/bootstrap.min.css&quot; integrity=&quot;sha384-B0vP5xmATw1+K9KRQjQERJvTumQW0nPEzvF6L/Z6nronJ3oUOFUFpCjEUQouq2+l&quot; crossorigin=&quot;anonymous&quot;&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.5.1.slim.min.js&quot; integrity=&quot;sha384-DfXdz2htPH0lsSSs5nCTpuj/zy4C+OGpamoFVy38MVBnE+IbbVYUew+OrCXaRkfj&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/js/bootstrap.bundle.min.js&quot; integrity=&quot;sha384-Piv4xVNRyMGpqkS2by6br4gNJ7DXjqk09RmUpJ8jgGtD7zP9yug3goQfGII0yAns&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://rdkit.org/rdkitjs/beta/RDKit_minimal.js&quot;&gt;&lt;/script&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;mols2grid&quot; class=&quot;gridcontainer&quot;&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;div class=&quot;list&quot;&gt;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left&quot;&gt;&lt;div class=&quot;data data-ID&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-img mols2grid-tooltip&quot; data-toggle=&quot;popover&quot; data-content=&quot;foo&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-Solubility style-Solubility&quot; style=&quot;&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-SMILES&quot; style=&quot;display: none;&quot;&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;
#       &lt;/div&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;ul class=&quot;pagination pt-3 pl-3 col&quot;&gt;&lt;/ul&gt;
#         &lt;div class=&quot;dropdown float-right col-1 py-3 mr-4&quot;&gt;
#           &lt;button class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; id=&quot;sortDropdown&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;
#             Sort by
#           &lt;/button&gt;
#           &lt;div class=&quot;dropdown-menu&quot; aria-labelledby=&quot;sortDropdownMenu&quot;&gt;
#
#
#             &lt;button class=&quot;dropdown-item sort-btn arrow-asc active&quot; type=&quot;button&quot; data-name=&quot;mols2grid-id&quot;&gt;Index&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-ID&quot;&gt;Id&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-Solubility&quot;&gt;Solubility&lt;/button&gt;
#
#
#           &lt;/div&gt;
#         &lt;/div&gt;
#         &lt;div class=&quot;input-group float-right col-4 py-3 mr-3 ml-2&quot;&gt;
#           &lt;input type=&quot;text&quot; id=&quot;searchbar&quot; class=&quot;form-control&quot; placeholder=&quot;Search&quot; aria-label=&quot;Search&quot; aria-describedby=&quot;basic-addon1&quot;&gt;
#           &lt;div class=&quot;input-group-append&quot;&gt;
#             &lt;button id=&quot;searchBtn&quot; class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;🔎&lt;/button&gt;
#             &lt;div class=&quot;dropdown-menu dropdown-menu-right&quot;&gt;
#               &lt;button id=&quot;txtSearch&quot; class=&quot;search-btn dropdown-item active&quot;&gt;Text&lt;/button&gt;
#               &lt;button id=&quot;smartsSearch&quot; class=&quot;search-btn dropdown-item&quot;&gt;SMARTS&lt;/button&gt;
#             &lt;/div&gt;
#           &lt;/div&gt;
#         &lt;/div&gt;
#       &lt;/div&gt;
#     &lt;/div&gt;
#     &lt;script&gt;
#       // RDKit
#       onRuntimeInitialized: initRDKitModule().then(function(instance) {
#         RDKitModule = instance;
#         console.log(&#x27;RDKit version: &#x27; + RDKitModule.version());
#       });
#       // pages
#       var listObj = new List(&#x27;mols2grid&#x27;,
#         {
#           valueNames: [{data: [&#x27;mols2grid-id&#x27;]}, &#x27;data-SMILES&#x27;, &#x27;data-ID&#x27;, &#x27;data-img&#x27;, &#x27;data-Solubility&#x27;, {attr: &#x27;data-content&#x27;, name: &#x27;mols2grid-tooltip&#x27;}, { attr: &#x27;style&#x27;, name: &#x27;style-Solubility&#x27; }],
#           item: &#x27;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left&quot;&gt;&lt;div class=&quot;data data-ID&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-img mols2grid-tooltip&quot; data-toggle=&quot;popover&quot; data-content=&quot;foo&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-Solubility style-Solubility&quot; style=&quot;&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-SMILES&quot; style=&quot;display: none;&quot;&gt;&lt;/div&gt;&lt;/div&gt;&#x27;,
#           page: 15,
#           pagination: {
#             name: &quot;pagination&quot;,
#             item: &#x27;&lt;li class=&quot;page-item&quot;&gt;&lt;a class=&quot;page page-link&quot; href=&quot;#&quot; onclick=&quot;event.preventDefault()&quot;&gt;&lt;/a&gt;&lt;/li&gt;&#x27;,
#             innerWindow: 1,
#             outerWindow: 1,
#           },
#         }
#       );
#       listObj.remove(&quot;mols2grid-id&quot;, &quot;0&quot;)
#       listObj.add([{&quot;mols2grid-id&quot;: 0, &quot;data-SMILES&quot;: &quot;CCC(C)CC&quot;, &quot;data-Solubility&quot;: -3.68, &quot;data-ID&quot;: 5, &quot;data-img&quot;: &quot;&lt;?xml version=&#x27;1.0&#x27; encoding=&#x27;iso-8859-1&#x27;?&gt;\n&lt;svg version=&#x27;1.1&#x27; baseProfile=&#x27;full&#x27;\n              xmlns=&#x27;http://www.w3.org/2000/svg&#x27;\n                      xmlns:rdkit=&#x27;http://www.rdkit.org/xml&#x27;\n                      xmlns:xlink=&#x27;http://www.w3.org/1999/xlink&#x27;\n                  xml:space=&#x27;preserve&#x27;\nwidth=&#x27;160px&#x27; height=&#x27;120px&#x27; viewBox=&#x27;0 0 160 120&#x27;&gt;\n&lt;!-- END OF HEADER --&gt;\n&lt;rect style=&#x27;opacity:1.0;fill:#FFFFFF;stroke:none&#x27; width=&#x27;160&#x27; height=&#x27;120&#x27; x=&#x27;0&#x27; y=&#x27;0&#x27;&gt; &lt;/rect&gt;\n&lt;path class=&#x27;bond-0 atom-0 atom-1&#x27; d=&#x27;M 21.515,50.6175 L 47.5,35.625&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-1 atom-1 atom-2&#x27; d=&#x27;M 47.5,35.625 L 80,54.375&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-lineca

# %% [markdown]
# If we click on the checkbox of the last, first and middle molecules on the first page (id 75, 5 and 40), we can retrieve the corresponding index and SMILES (in the same order):

# %%
# retrieve the index and SMILES of your selection
mols2grid.selection
# Out:
# {14: 'c1c(C)cc2ccccc2c1C', 0: 'CCC(C)CC', 7: 'c1ccccc1CC'}

# %% [markdown]
# You can also retrieve your selection (and the data that came with it) in a pandas DataFrame if you use the `MolGrid` class (which is used by the `mols2grid.display` function implicitely). The MolGrid class takes a dataframe as input, but you can also use the `MolGrid.from_mols` and `MolGrid.from_sdf` classmethods if needed.

# %%
# example dataframe
import pandas as pd

smiles = ["CCO", "c1ccccc1", "N", "CO", "O=S(=O)(-O)(-O)", "CCC", "CCC=O"]
df = pd.DataFrame({"smi": smiles,
                   "id": range(1, len(smiles) + 1)})
# setup the grid
mg = mols2grid.MolGrid(df, smiles_col="smi", size=(110, 90))
mg.display(subset=["id", "img"], n_cols=7)
# Out:
# <iframe class="mols2grid-iframe" width=100% height="188" frameborder="0" srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#       #mols2grid.gridcontainer {
#         display: block;
#         padding-left: 1em;
#         max-width: 798px;
#         width: 798px;
#       }
#       #mols2grid .cell {
#         border: 1px solid #cccccc;
#         text-align: center;
#         vertical-align: top;
#         max-width: 110px;
#         width: 110px;
#         font-family: &#x27;DejaVu&#x27;, sans-serif;
#         font-size: 12pt;
#         padding: 0;
#         margin: 0;
#         float: left;
#       }
#       #mols2grid .cell:hover {
#         background-color: #e7e7e7;
#       }
#       #mols2grid .cell img, #mols2grid .cell svg {
#         max-width: 100%;
#         height: auto;
#         padding: 0;
#       }
#       #mols2grid .data {
#         overflow: hidden;
#         white-space: nowrap;
#         text-overflow: ellipsis;
#         display: block;
#       }
#       #mols2grid .arrow-asc:after {
#         content: &#x27;↑&#x27;;
#         text-align: right;
#         float:right;
#       }
#       #mols2grid .arrow-desc:after {
#         content: &#x27;↓&#x27;;
#         text-align: right;
#         float:right;
#       }
#     &lt;/style&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/list.js/2.3.1/list.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/css/bootstrap.min.css&quot; integrity=&quot;sha384-B0vP5xmATw1+K9KRQjQERJvTumQW0nPEzvF6L/Z6nronJ3oUOFUFpCjEUQouq2+l&quot; crossorigin=&quot;anonymous&quot;&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.5.1.slim.min.js&quot; integrity=&quot;sha384-DfXdz2htPH0lsSSs5nCTpuj/zy4C+OGpamoFVy38MVBnE+IbbVYUew+OrCXaRkfj&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/js/bootstrap.bundle.min.js&quot; integrity=&quot;sha384-Piv4xVNRyMGpqkS2by6br4gNJ7DXjqk09RmUpJ8jgGtD7zP9yug3goQfGII0yAns&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://rdkit.org/rdkitjs/beta/RDKit_minimal.js&quot;&gt;&lt;/script&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;mols2grid&quot; class=&quot;gridcontainer&quot;&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;div class=&quot;list&quot;&gt;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left&quot;&gt;&lt;div class=&quot;data data-id&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-smi&quot; style=&quot;display: none;&quot;&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;
#       &lt;/div&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;ul class=&quot;pagination pt-3 pl-3 col&quot;&gt;&lt;/ul&gt;
#         &lt;div class=&quot;dropdown float-right col-1 py-3 mr-4&quot;&gt;
#           &lt;button class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; id=&quot;sortDropdown&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;
#             Sort by
#           &lt;/button&gt;
#           &lt;div class=&quot;dropdown-menu&quot; aria-labelledby=&quot;sortDropdownMenu&quot;&gt;
#
#
#             &lt;button class=&quot;dropdown-item sort-btn arrow-asc active&quot; type=&quot;button&quot; data-name=&quot;mols2grid-id&quot;&gt;Index&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-id&quot;&gt;Id&lt;/button&gt;
#
#
#           &lt;/div&gt;
#         &lt;/div&gt;
#         &lt;div class=&quot;input-group float-right col-4 py-3 mr-3 ml-2&quot;&gt;
#           &lt;input type=&quot;text&quot; id=&quot;searchbar&quot; class=&quot;form-control&quot; placeholder=&quot;Search&quot; aria-label=&quot;Search&quot; aria-describedby=&quot;basic-addon1&quot;&gt;
#           &lt;div class=&quot;input-group-append&quot;&gt;
#             &lt;button id=&quot;searchBtn&quot; class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;🔎&lt;/button&gt;
#             &lt;div class=&quot;dropdown-menu dropdown-menu-right&quot;&gt;
#               &lt;button id=&quot;txtSearch&quot; class=&quot;search-btn dropdown-item active&quot;&gt;Text&lt;/button&gt;
#               &lt;button id=&quot;smartsSearch&quot; class=&quot;search-btn dropdown-item&quot;&gt;SMARTS&lt;/button&gt;
#             &lt;/div&gt;
#           &lt;/div&gt;
#         &lt;/div&gt;
#       &lt;/div&gt;
#     &lt;/div&gt;
#     &lt;script&gt;
#       // RDKit
#       onRuntimeInitialized: initRDKitModule().then(function(instance) {
#         RDKitModule = instance;
#         console.log(&#x27;RDKit version: &#x27; + RDKitModule.version());
#       });
#       // pages
#       var listObj = new List(&#x27;mols2grid&#x27;,
#         {
#           valueNames: [{data: [&#x27;mols2grid-id&#x27;]}, &#x27;data-smi&#x27;, &#x27;data-id&#x27;, &#x27;data-img&#x27;],
#           item: &#x27;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left&quot;&gt;&lt;div class=&quot;data data-id&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-smi&quot; style=&quot;display: none;&quot;&gt;&lt;/div&gt;&lt;/div&gt;&#x27;,
#           page: 21,
#           pagination: {
#             name: &quot;pagination&quot;,
#             item: &#x27;&lt;li class=&quot;page-item&quot;&gt;&lt;a class=&quot;page page-link&quot; href=&quot;#&quot; onclick=&quot;event.preventDefault()&quot;&gt;&lt;/a&gt;&lt;/li&gt;&#x27;,
#             innerWindow: 1,
#             outerWindow: 1,
#           },
#         }
#       );
#       listObj.remove(&quot;mols2grid-id&quot;, &quot;0&quot;)
#       listObj.add([{&quot;data-smi&quot;: &quot;CCO&quot;, &quot;data-id&quot;: 1, &quot;mols2grid-id&quot;: 0, &quot;data-img&quot;: &quot;&lt;?xml version=&#x27;1.0&#x27; encoding=&#x27;iso-8859-1&#x27;?&gt;\n&lt;svg version=&#x27;1.1&#x27; baseProfile=&#x27;full&#x27;\n              xmlns=&#x27;http://www.w3.org/2000/svg&#x27;\n                      xmlns:rdkit=&#x27;http://www.rdkit.org/xml&#x27;\n                      xmlns:xlink=&#x27;http://www.w3.org/1999/xlink&#x27;\n                  xml:space=&#x27;preserve&#x27;\nwidth=&#x27;110px&#x27; height=&#x27;90px&#x27; viewBox=&#x27;0 0 110 90&#x27;&gt;\n&lt;!-- END OF HEADER --&gt;\n&lt;rect style=&#x27;opacity:1.0;fill:#FFFFFF;stroke:none&#x27; width=&#x27;110&#x27; height=&#x27;90&#x27; x=&#x27;0&#x27; y=&#x27;0&#x27;&gt; &lt;/rect&gt;\n&lt;path class=&#x27;bond-0 atom-0 atom-1&#x27; d=&#x27;M 105,51.1326 L 67.191,29.2579&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-1 atom-1 atom-2&#x27; d=&#x27;M 67.191,29.2579 L 53.0737,37.3952&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-1 atom-1 atom-2&#x27; d=&#x27;M 53.0737,37.3952 L 38.9565,45.5324&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#FF0000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path  class=&#x27;atom-2&#x27; d=&#x27;M 5 41.8988\nL 7.51594 41.8988\nL 7.51594 49.7873\nL 17.0031 49.7873\nL 17.0031 41.8988\nL 19.5191 41.8988\nL 19.5191 60.4538\nL 17.0031 60.4538\nL 17.0031 51.8839\nL 7.51594 51.8839\nL 7.51594 60.4538\nL 5 60.4538\nL 5 41.8988\n&#x27; fill=&#x27;#FF0000&#x27;/&gt;\n&lt;path  class=&#x27;atom-2&#x27; d=&#x27;M 20.8295 51.1239\nQ 20.8295 46.6686, 23.0309 44.1788\nQ 25.2324 41.6891, 29.347 41.6891\nQ 33.4616 41.6

# %%
# retrieve your selection as a dataframe
mg.get(mols2grid.selection)
# Out:
#      smi  id
# 0    CCO   1
# 6  CCC=O   7

# %%
# retrieve specific indexes
mg.get([0, 4])
# Out:
#                smi  id
# 0              CCO   1
# 4  O=S(=O)(-O)(-O)   5

# %% [markdown]
# Here's an example with annotations and highlights of molecules, and more complex drawing options:

# %%
from rdkit import Chem
from rdkit.Chem import Draw

# drawing options
opts = Draw.MolDrawOptions()
opts.useBWAtomPalette() # black and white atom palette
opts.setHighlightColour((0, 1, 1)) # cyan highlights
opts.setAnnotationColour((0.8, 0, 0.8)) # purple notes
opts.annotationFontScale = 0.8 # notes font scale
opts.clearBackground = False # transparent bg
Draw.SetComicMode(opts) # xkcd style

mols = [Chem.MolFromSmiles(smi) for smi in smiles]
# annotate atom in first molecule
mols[0].GetAtomWithIdx(0).SetProp("atomNote", "1")
# annotate bond
mols[1].GetBondWithIdx(0).SetProp("bondNote", "2")
# highlight atoms manually
mols[3].__sssAtoms = [0]
# highlight atoms through SMARTS querry
mols[4].GetSubstructMatch(Chem.MolFromSmarts("S=O"))
# display
mols2grid.display(mols, template="table", n_cols=7,
                  subset=["img"], size=(120, 100),
                  MolDrawOptions=opts, selection=False)
# Out:
# <iframe class="mols2grid-iframe" width=100% height="104" frameborder="0" srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#       #mols2grid table {
#         border-collapse: collapse;
#       }
#       #mols2grid table, tr, td {
#         border: none;
#       }
#       #mols2grid td {
#         border: 1px solid #cccccc;
#         text-align: center;
#         vertical-align: top;
#         max-width: 120px;
#         width: 120px;
#         font-family: &#x27;DejaVu&#x27;, sans-serif;
#         font-size: 12pt;
#         margin: 0;
#         padding: 0;
#       }
#       #mols2grid td div {
#         padding: 0;
#         margin: 0;
#       }
#       #mols2grid td div img {
#         max-width: 120px;
#         width: 120px;
#         height: auto;
#         padding: 0;
#       }
#       #mols2grid td:hover {
#         background-color: #e7e7e7;
#       }
#       #mols2grid .data {
#         overflow: hidden;
#         white-space: nowrap;
#         text-overflow: ellipsis;
#         display: block;
#       }
#       #mols2grid tr {
#         page-break-inside: avoid !important;
#       }
#     &lt;/style&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/css/bootstrap.min.css&quot; integrity=&quot;sha384-B0vP5xmATw1+K9KRQjQERJvTumQW0nPEzvF6L/Z6nronJ3oUOFUFpCjEUQouq2+l&quot; crossorigin=&quot;anonymous&quot;&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.5.1.slim.min.js&quot; integrity=&quot;sha384-DfXdz2htPH0lsSSs5nCTpuj/zy4C+OGpamoFVy38MVBnE+IbbVYUew+OrCXaRkfj&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/js/bootstrap.bundle.min.js&quot; integrity=&quot;sha384-Piv4xVNRyMGpqkS2by6br4gNJ7DXjqk09RmUpJ8jgGtD7zP9yug3goQfGII0yAns&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;table id=&quot;mols2grid&quot;&gt;
#       &lt;tbody&gt;
#         &lt;tr class=&quot;row-0&quot;&gt;
# &lt;td class=&quot;col-0&gt;&quot;
# &lt;div class=&quot;cell-0&quot;&gt;
# &lt;div class=&quot;data data-img&quot;&gt;&lt;?xml version=&#x27;1.0&#x27; encoding=&#x27;iso-8859-1&#x27;?&gt;
# &lt;svg version=&#x27;1.1&#x27; baseProfile=&#x27;full&#x27;
#               xmlns=&#x27;http://www.w3.org/2000/svg&#x27;
#                       xmlns:rdkit=&#x27;http://www.rdkit.org/xml&#x27;
#                       xmlns:xlink=&#x27;http://www.w3.org/1999/xlink&#x27;
#                   xml:space=&#x27;preserve&#x27;
# width=&#x27;120px&#x27; height=&#x27;100px&#x27; viewBox=&#x27;0 0 120 100&#x27;&gt;
# &lt;!-- END OF HEADER --&gt;
# &lt;path class=&#x27;bond-0 atom-0 atom-1&#x27; d=&#x27;M 109.317,57.267 L 99.1661,51.2886 L 89.2794,44.8611 L 78.6581,39.6811 L 68.7126,33.3534&#x27; style=&#x27;fill:none;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1;&#x27; /&gt;
# &lt;path class=&#x27;bond-1 atom-1 atom-2&#x27; d=&#x27;M 69.7126,34.3534 L 59.2094,40.0065 L 49.0243,46.2115 L 38.7235,52.2158&#x27; style=&#x27;fill:none;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1;&#x27; /&gt;
# &lt;path  class=&#x27;atom-2&#x27; d=&#x27;M 6.33302 66.1466
# Q 5.97614 66.1466, 5.70162 65.8995
# Q 5.45455 65.625, 5.45455 65.2681
# L 5.45455 48.3025
# Q 5.45455 47.9456, 5.70162 47.6986
# Q 5.94869 47.4515, 6.33302 47.4515
# Q 6.71735 47.4515, 6.96443 47.6986
# Q 7.23895 47.9456, 7.23895 48.3025
# L 7.23895 56.5382
# L 18.9886 54.8911
# L 18.9886 48.3025
# Q 18.9886 47.9456, 19.2356 47.6986
# Q 19.4827 47.4515, 19.867 47.4515
# Q 20.2239 47.4515, 20.471 47.6986
# Q 20.7455 47.9456, 20.7455 48.3025
# L 20.7455 65.2681
# Q 20.7455 65.625, 20.471 65.8995
# Q 20.2239 66.1466, 19.867 66.1466
# Q 19.5102 66.1466, 19.2356 65.8995
# Q 18.9886 65.625, 18.9886 65.2681
# L 18.9886 56.6755
# L 7.23895 58.2952
# L 7.23895 65.2681
# Q 7.23895 65.625, 6.96443 65.8995
# Q 6.6899 66.1466, 6.33302 66.1466
# &#x27; fill=&#x27;#000000&#x27;/&gt;
# &lt;path  class=&#x27;atom-2&#x27; d=&#x27;M 28.9812 66.1466
# Q 26.9772 66.1466, 25.385 65.0485
# Q 23.8202 63.9229, 22.9417 61.9738
# Q 22.0632 59.9972, 22.0632 57.554
# Q 22.0632 54.8087, 23.1613 52.4753
# Q 24.2594 50.1418, 26.1262 48.7967
# Q 27.9929 47.4241, 30.1617 47.4241
# Q 32.1931 47.4241, 33.7579 48.5496
# Q 35.3227 49.6477, 36.2012 51.6243
# Q 37.0797 53.6008, 37.0797 56.0441
# Q 37.0797 58.7893, 35.9816 61.1228
# Q 34.8835 63.4288, 33.0167 64.8014
# Q 31.15 66.1466, 28.9812 66.1466
# M 29.091 64.4445
# Q 30.7382 64.4445, 32.1382 63.319
# Q 33.5658 62.1934, 34.4168 60.2718
# Q 35.2678 58.3501, 35.2678 56.1265
# Q 35.2678 54.0675, 34.5815 52.4753
# Q 33.8952 50.8831, 32.6873 50.0046
# Q 31.5068 49.1261, 30.0244 49.1261
# Q 28.4047 49.1261, 26.9772 50.2516
# Q 25.5497 51.3497, 24.6986 53.2714
# Q 23.8751 55.1931, 23.8751 57.4991
# Q 23.8751 59.5854, 24.5614 61.1777
# Q 25.2751 62.7425, 26.4556 63.5935
# Q 27.6361 64.4445, 29.091 64.4445
# &#x27; fill=&#x27;#000000&#x27;/&gt;
# &lt;path  class=&#x27;note&#x27; d=&#x27;M 112.217 54.3003
# Q 111.932 54.3003, 111.734 54.1026
# Q 111.537 53.905, 111.537 53.6195
# Q 111.537 53.3339, 111.734 53.1363
# Q 111.932 52.9167, 112.217 52.9167
# L 114.062 52.9167
# L 114.238 41.9138
# L 112.657 43.6048
# Q 112.459 43.8245, 112.152 43.8245
# Q 111.866 43.8245, 111.668 43.6268
# Q 111.471 43.4072, 111.471 43.1217
# Q 111.471 42.8581, 111.668 42.6605
# L 114.436 39.6517
# Q 114.523 39.5638, 114.655 39.498
# Q 114.809 39.4321, 114.919 39.4321
# Q 115.226 39.4321, 115.424 39.6517
# Q 115.622 39.8493, 115.622 40.1349
# L 115.446 52.9167
# L 116.895 52.9167
# Q 117.225 52.9167, 117.422 53.1363
# Q 117.62 53.3339, 117.62 53.6195
# Q 117.62 53.905, 117.4 54.1026
# Q 117.203 54.3003, 116.939 54.3003
# L 112.217 54.3003
# &#x27; fill=&#x27;#CC00CC&#x27;/&gt;
# &lt;/svg&gt;
# &lt;/div&gt;
# &lt;/div&gt;
# &lt;/td&gt;
# &lt;td class=&quot;col-1&gt;&quot;
# &lt;div class=&quot;cell-1&quot;&gt;
# &lt;div class=&quot;data data-img&quot;&gt;&lt;?xml version=&#x27;1.0&#x27; encoding=&#x27;iso-8859-1&#x27;?&gt;
# &lt;svg version=&#x27;1.1&#x27; baseProfile=&#x27;full&#x27;
#               xmlns=&#x27;http://www.w3.org/2000/svg&#x27;
#                       xmlns:rdkit=&#x27;http://www.rdkit.org/xml&#x27;
#                       xmlns:xlink=&#x27;http://www.w3.org/1999/xlink&#x27;
#                   xml:space=&#x27;preserve&#x27;
# width=&#x27;120px&#x27; height=&#x27;100px&#x27; viewBox=&#x27;0 0 120 100&#x27;&gt;
# &lt;!-- END OF HEADER --&gt;
# &lt;path class=&#x27;bond-0 atom-0 atom-1&#x27; d=&#x27;M 27.9273,72.2 L 27.9364,61.0864 L 27.4852,49.9723 L 27.5518,38.8588 L 27.9636,27.7455&#x27; style=&#x27;fill:none;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1;&#x27; /&gt;
# &lt;path class=&#x27;bond-0 atom-0 atom-1&#x27; d=&#x27;M 36.1145,65.3884 L 35.6628,55.1153 L 36.5917,44.8433 L 36.14,34.5702&#x27; style=&#x27;fill:none;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1;&#x27; /&gt;
# &lt;path class=&#x27;bond-5 atom-5 atom-0&#x27; d=&#x27;M 67.2727,94.9545 L 57.2146,89.2158 L 46.8739,83.9781 L 36.9854,77.9387 L 26.9273,72.2&#x27; style=&#x27;fill:none;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1;&#x27; /&gt;
# &lt;path class=&#x27;bond-1 atom-1 atom-2&#x27; d=&#x27;M 26.9636,27.7455 L 37.2564,22.4215 L 47.3801,16.7966 L 57.0809,10.4196 L 67.3455,5.04545&#x27; style=&#x27;fill:none;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1;&#x27; /&gt;
# &lt;path class=&#x27;bond-2 atom-2 atom-3&#x27; d=&#x27;M 67.3455,5.04545 L 76.9034,10.5341 L 86.8021,15.4224 L 95.9342,21.6616 L 105.691,26.8&#x27; style=&#x27;fill:none;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1;&#x27; /&gt;
# &lt;path class=&#x27;bond-2 atom-2 atom-3&#x27; d=&#x27;M 68.1512,15.5413 L 77.5785,20.0622 L 86.6495,25.2405 L 95.693,30.4695&#x27; style=&#x27;fill:none;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1;&#x27; /&gt;
# &lt;path class=&#x27;bond-3 atom-3 atom-4&#x27; d=&#x27
